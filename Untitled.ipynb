# %%
import cv2
import matplotlib.pyplot as plt

# 画像を読み込む
image = cv2.imread('Data/sample.png')

# BGRからRGBに変換して表示
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# [ WARN:0@2.875] global loadsave.cpp:275 findDecoder imread_('Data/sample.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 8
#       5 image = cv2.imread('Data/sample.png')
#       7 # BGRからRGBに変換して表示
# ----> 8 plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#       9 plt.show()
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
